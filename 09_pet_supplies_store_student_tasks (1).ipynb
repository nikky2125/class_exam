# %% [markdown]
# # Pet Supplies Store - Student Practice Notebook
#
# Dataset file: `09_pet_supplies_store.csv`
#
# Solve each task in the empty code cell below it.

# %% [markdown]
# ## Task 1
#
# Load the dataset into a pandas DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("09_pet_supplies_store.csv")

# %% [markdown]
# ## Task 2
#
# Display the first 10 rows of the DataFrame.

# %%
df.head(10)
# Out:
#       Order_ID  Order_Date Customer_Segment   Region Product_Category  \
# 0  09ORD100522  2025-09-20        Cat Owner     East      Accessories
# 1  09ORD100738  2024-07-17        Dog Owner     East             Food
# 2  09ORD100741  2025-03-17       Bird Owner    South         Grooming
# 3  09ORD100661  2024-01-30        Cat Owner     West         Grooming
# 4  09ORD100412  2024-10-27        Cat Owner    South      Accessories
# 5  09ORD100679  2024-09-22        Dog Owner  Central       Healthcare
# 6  09ORD100627  2024-04-10         Pet Shop  Central             Toys
# 7  09ORD100514  2025-02-02         Pet Shop  Central             Toys
# 8  09ORD100860  2025-08-26         Pet Shop    North      Accessories
# 9  09ORD100137  2025-06-02       Bird Owner  Central             Food
#
#      Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 0            Wallet         6      316.57                 4      1823.44
# 1        Debit Card         2     3613.55                14      6215.31
# 2               UPI         2     2085.62                22      3253.57
# 3               UPI         4     6568.81                25     19706.43
# 4               UPI         4     7566.14                21     23909.00
# 5       Credit Card         1     6892.45                14      5927.51
# 6       Credit Card         3      633.35                24      1444.04
# 7  Cash on Delivery         1     7549.88                 3      7323.38
# 8       Credit Card         2     2078.56                 1      4115.55
# 9               UPI         6     1484.59                 3      8640.31

# %% [markdown]
# ## Task 3
#
# Display the last 7 rows of the DataFrame.

# %%
df.tail(7)
# Out:
#         Order_ID  Order_Date Customer_Segment   Region Product_Category  \
# 993  09ORD100701  2025-01-09        Cat Owner     East      Accessories
# 994  09ORD100072  2024-09-01        Cat Owner    North       Healthcare
# 995  09ORD100107  2025-11-15       Bird Owner  Central      Accessories
# 996  09ORD100271  2025-05-28       Bird Owner     East       Healthcare
# 997  09ORD100861  2025-08-02        Dog Owner     West         Grooming
# 998  09ORD100436  2024-03-30        Cat Owner    South             Food
# 999  09ORD100103  2025-07-25         Pet Shop  Central       Healthcare
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 993         Wallet         5     2656.78                 1     13151.06
# 994    Credit Card         4     2200.37                13      7657.29
# 995    Credit Card         1     4969.98                16      4174.78
# 996         Wallet         3     5971.04                20     14330.50
# 997         Wallet         2     8184.28                 4     15713.82
# 998     Debit Card         1     1182.02                 6      1111.10
# 999            UPI         2     8970.15                19     14531.64

# %% [markdown]
# ## Task 4
#
# Check the shape of the DataFrame.

# %%
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# ## Task 5
#
# List all column names.

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_Segment', 'Region',
#        'Product_Category', 'Payment_Method', 'Quantity', 'Unit_Price',
#        'Discount_Percent', 'Order_Value'],
#       dtype='str')

# %% [markdown]
# ## Task 6
#
# Check the data types of all columns.

# %%
df.dtypes
# Out:
# Order_ID                str
# Order_Date              str
# Customer_Segment        str
# Region                  str
# Product_Category        str
# Payment_Method          str
# Quantity              int64
# Unit_Price          float64
# Discount_Percent      int64
# Order_Value         float64
# dtype: object

# %% [markdown]
# ## Task 7
#
# Display basic information using info().

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   str
#  1   Order_Date        1000 non-null   str
#  2   Customer_Segment  1000 non-null   str
#  3   Region            1000 non-null   str
#  4   Product_Category  1000 non-null   str
#  5   Payment_Method    1000 non-null   str
#  6   Quantity          1000 non-null   int64
#  7   Unit_Price        1000 non-null   float64
#  8   Discount_Percent  1000 non-null   int64
#  9   Order_Value       1000 non-null   float64
# dtypes: float64(2), int64(2), str(6)
# memory usage: 78.3 KB

# %% [markdown]
# ## Task 8
#
# Generate summary statistics for numerical columns.

# %%
df.describe()
# Out:
#           Quantity   Unit_Price  Discount_Percent   Order_Value
# count  1000.000000  1000.000000       1000.000000   1000.000000
# mean      2.733000  4500.647640         15.375000  10272.179510
# std       1.746643  2509.714931          8.757115   9554.934118
# min       1.000000    53.730000          0.000000     50.510000
# 25%       1.000000  2394.402500          8.000000   3707.365000
# 50%       2.000000  4437.285000         16.000000   6780.120000
# 75%       4.000000  6588.985000         23.000000  13634.375000
# max       6.000000  8989.200000         30.000000  51863.680000

# %% [markdown]
# ## Task 9
#
# Generate summary statistics for categorical columns.

# %%
df.describe(include='object')
# Out:
# C:\Users\N.Nikhitha\AppData\Local\Temp\ipykernel_36476\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#            Order_ID  Order_Date Customer_Segment Region Product_Category  \
# count          1000        1000             1000   1000             1000
# unique         1000         557                4      5                5
# top     09ORD100522  2024-10-27        Dog Owner   West             Food
# freq              1           5              255    223              226
#
#        Payment_Method
# count            1000
# unique              5
# top               UPI
# freq              210

# %% [markdown]
# ## Task 10
#
# Check whether the DataFrame contains any missing values.

# %%
df.isna().any()
# Out:
# Order_ID            False
# Order_Date          False
# Customer_Segment    False
# Region              False
# Product_Category    False
# Payment_Method      False
# Quantity            False
# Unit_Price          False
# Discount_Percent    False
# Order_Value         False
# dtype: bool

# %% [markdown]
# ## Task 11
#
# Count the missing values in each column.

# %%
df.isna().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_Segment    0
# Region              0
# Product_Category    0
# Payment_Method      0
# Quantity            0
# Unit_Price          0
# Discount_Percent    0
# Order_Value         0
# dtype: int64

# %% [markdown]
# ## Task 12
#
# Check whether there are any duplicate rows.

# %%
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# ## Task 13
#
# Count the duplicate rows in the DataFrame.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Task 14
#
# Drop duplicate rows if any exist.

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# ## Task 15
#
# Convert the Order_Date column to datetime format.

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Order_Date'].dtype
# Out:
# dtype('<M8[us]')

# %% [markdown]
# ## Task 16
#
# Extract only the year from Order_Date into a new column named Order_Year.

# %%
df['Order_Year'] = df['Order_Date'].dt.year
df[['Order_Date','Order_Year']].head()
# Out:
#   Order_Date  Order_Year
# 0 2025-09-20        2025
# 1 2024-07-17        2024
# 2 2025-03-17        2025
# 3 2024-01-30        2024
# 4 2024-10-27        2024

# %% [markdown]
# ## Task 17
#
# Extract the month name from Order_Date into a new column named Order_Month.

# %%
df['Order_Month'] = df['Order_Date'].dt.month_name()
df[['Order_Date','Order_Month']].head()
# Out:
#   Order_Date Order_Month
# 0 2025-09-20   September
# 1 2024-07-17        July
# 2 2025-03-17       March
# 3 2024-01-30     January
# 4 2024-10-27     October

# %% [markdown]
# ## Task 18
#
# Extract the weekday name from Order_Date into a new column named Order_Day.

# %%
df['Order_Day'] = df['Order_Date'].dt.day_name()
df[['Order_Date','Order_Day']].head()
# Out:
#   Order_Date  Order_Day
# 0 2025-09-20   Saturday
# 1 2024-07-17  Wednesday
# 2 2025-03-17     Monday
# 3 2024-01-30    Tuesday
# 4 2024-10-27     Sunday

# %% [markdown]
# ## Task 19
#
# Display a random sample of 12 rows.

# %%
df.sample(12)
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 402  09ORD100540 2025-07-30        Dog Owner    North      Accessories
# 425  09ORD100368 2024-01-09        Dog Owner    North       Healthcare
# 723  09ORD100280 2025-08-12         Pet Shop  Central             Toys
# 324  09ORD100778 2024-11-23        Dog Owner    North             Food
# 263  09ORD100267 2025-08-10       Bird Owner     West      Accessories
# 992  09ORD100021 2024-05-15        Cat Owner    North       Healthcare
# 788  09ORD100473 2024-06-26        Dog Owner  Central       Healthcare
# 129  09ORD100801 2025-08-04        Dog Owner    South         Grooming
# 381  09ORD100146 2024-04-08         Pet Shop    North             Toys
# 233  09ORD100576 2024-08-29        Dog Owner  Central         Grooming
# 840  09ORD100547 2024-01-15         Pet Shop     West       Healthcare
# 72   09ORD100591 2025-02-08        Dog Owner    South             Toys
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 402               UPI         2     4599.07                20      7358.51
# 425            Wallet         4     7977.23                22     24888.96
# 723        Debit Card         6     2686.96                24     12252.54
# 324               UPI         5     3580.44                28     12889.58
# 263        Debit Card         1     6894.20                21      5446.42
# 992            Wallet         6      840.22                19      4083.47
# 788        Debit Card         1     2057.19                14      1769.18
# 129            Wallet         3     4823.19                 4     13890.79
# 381  Cash on Delivery         1     3128.44                 4      3003.30
# 233       Credit Card         1     4477.18                 2      4387.64
# 840        Debit Card         1     7424.93                 6      6979.43
# 72   Cash on Delivery         4     1446.09                19      4685.33
#
#      Order_Year Order_Month  Order_Day
# 402        2025        July  Wednesday
# 425        2024     January    Tuesday
# 723        2025      August    Tuesday
# 324        2024    November   Saturday
# 263        2025      August     Sunday
# 992        2024         May  Wednesday
# 788        2024        June  Wednesday
# 129        2025      August     Monday
# 381        2024       April     Monday
# 233        2024      August   Thursday
# 840        2024     January     Monday
# 72         2025    February   Saturday

# %% [markdown]
# ## Task 20
#
# Rename Discount_Percent to Discount.

# %%
df = df.rename(columns={'Discount_Percent':'Discount'})
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_Segment',
#  'Region',
#  'Product_Category',
#  'Payment_Method',
#  'Quantity',
#  'Unit_Price',
#  'Discount',
#  'Order_Value',
#  'Order_Year',
#  'Order_Month',
#  'Order_Day']

# %% [markdown]
# ## Task 21
#
# Change the column name back from Discount to Discount_Percent.

# %%
df = df.rename(columns={'Discount':'Discount_Percent'})
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_Segment',
#  'Region',
#  'Product_Category',
#  'Payment_Method',
#  'Quantity',
#  'Unit_Price',
#  'Discount_Percent',
#  'Order_Value',
#  'Order_Year',
#  'Order_Month',
#  'Order_Day']

# %% [markdown]
# ## Task 22
#
# Set Order_ID as the index.

# %%
df = df.set_index('Order_ID')
df.head()
# Out:
#             Order_Date Customer_Segment Region Product_Category  \
# Order_ID
# 09ORD100522 2025-09-20        Cat Owner   East      Accessories
# 09ORD100738 2024-07-17        Dog Owner   East             Food
# 09ORD100741 2025-03-17       Bird Owner  South         Grooming
# 09ORD100661 2024-01-30        Cat Owner   West         Grooming
# 09ORD100412 2024-10-27        Cat Owner  South      Accessories
#
#             Payment_Method  Quantity  Unit_Price  Discount_Percent  \
# Order_ID
# 09ORD100522         Wallet         6      316.57                 4
# 09ORD100738     Debit Card         2     3613.55                14
# 09ORD100741            UPI         2     2085.62                22
# 09ORD100661            UPI         4     6568.81                25
# 09ORD100412            UPI         4     7566.14                21
#
#              Order_Value  Order_Year Order_Month  Order_Day
# Order_ID
# 09ORD100522      1823.44        2025   September   Saturday
# 09ORD100738      6215.31        2024        July  Wednesday
# 09ORD100741      3253.57        2025       March     Monday
# 09ORD100661     19706.43        2024     January    Tuesday
# 09ORD100412     23909.00        2024     October     Sunday

# %% [markdown]
# ## Task 23
#
# Reset the index back to default integer index.

# %%
df = df.reset_index()
df.head()
# Out:
#       Order_ID Order_Date Customer_Segment Region Product_Category  \
# 0  09ORD100522 2025-09-20        Cat Owner   East      Accessories
# 1  09ORD100738 2024-07-17        Dog Owner   East             Food
# 2  09ORD100741 2025-03-17       Bird Owner  South         Grooming
# 3  09ORD100661 2024-01-30        Cat Owner   West         Grooming
# 4  09ORD100412 2024-10-27        Cat Owner  South      Accessories
#
#   Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0         Wallet         6      316.57                 4      1823.44
# 1     Debit Card         2     3613.55                14      6215.31
# 2            UPI         2     2085.62                22      3253.57
# 3            UPI         4     6568.81                25     19706.43
# 4            UPI         4     7566.14                21     23909.00
#
#    Order_Year Order_Month  Order_Day
# 0        2025   September   Saturday
# 1        2024        July  Wednesday
# 2        2025       March     Monday
# 3        2024     January    Tuesday
# 4        2024     October     Sunday

# %% [markdown]
# ## Task 24
#
# Sort the DataFrame by Order_Value in descending order.

# %%
df.sort_values('Order_Value', ascending=False).head()
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 601  09ORD100128 2025-11-11        Cat Owner  Central         Grooming
# 505  09ORD100961 2025-11-14        Cat Owner     West             Food
# 178  09ORD100803 2024-03-15       Bird Owner    South      Accessories
# 158  09ORD100061 2025-03-16       Bird Owner    North             Toys
# 589  09ORD100176 2025-06-25       Bird Owner  Central       Healthcare
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 601        Debit Card         6     8731.26                 1     51863.68
# 505        Debit Card         6     8305.05                 0     49830.30
# 178       Credit Card         6     8423.89                 3     49027.04
# 158        Debit Card         6     8946.68                16     45091.27
# 589  Cash on Delivery         6     8214.72                10     44359.49
#
#      Order_Year Order_Month  Order_Day
# 601        2025    November    Tuesday
# 505        2025    November     Friday
# 178        2024       March     Friday
# 158        2025       March     Sunday
# 589        2025        June  Wednesday

# %% [markdown]
# ## Task 25
#
# Sort the DataFrame by Quantity ascending and Unit_Price descending.

# %%
df.sort_values(['Quantity','Unit_Price'], ascending=[True, False]).head()
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 735  09ORD100836 2024-08-10         Pet Shop    North             Toys
# 544  09ORD100118 2025-10-03         Pet Shop  Central             Food
# 410  09ORD100517 2024-03-04        Cat Owner     West             Food
# 707  09ORD100147 2025-10-22         Pet Shop  Central         Grooming
# 796  09ORD100856 2024-11-29        Dog Owner     East      Accessories
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 735  Cash on Delivery         1     8989.20                13      7820.60
# 544  Cash on Delivery         1     8925.39                28      6426.28
# 410  Cash on Delivery         1     8917.39                18      7312.26
# 707       Credit Card         1     8888.06                16      7465.97
# 796            Wallet         1     8886.98                30      6220.89
#
#      Order_Year Order_Month  Order_Day
# 735        2024      August   Saturday
# 544        2025     October     Friday
# 410        2024       March     Monday
# 707        2025     October  Wednesday
# 796        2024    November     Friday

# %% [markdown]
# ## Task 26
#
# Filter all rows where Region is North.

# %%
df[df['Region'] == 'North'].head()
# Out:
#        Order_ID Order_Date Customer_Segment Region Product_Category  \
# 8   09ORD100860 2025-08-26         Pet Shop  North      Accessories
# 11  09ORD100077 2024-02-08        Dog Owner  North         Grooming
# 13  09ORD100974 2024-08-01        Dog Owner  North             Toys
# 19  09ORD100320 2024-07-21        Dog Owner  North       Healthcare
# 22  09ORD100372 2024-03-06        Cat Owner  North       Healthcare
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 8        Credit Card         2     2078.56                 1      4115.55
# 11       Credit Card         4     4653.64                16     15636.23
# 13  Cash on Delivery         2      990.97                20      1585.55
# 19        Debit Card         1     4788.07                15      4069.86
# 22               UPI         6     6997.30                 0     41983.80
#
#     Order_Year Order_Month  Order_Day
# 8         2025      August    Tuesday
# 11        2024    February   Thursday
# 13        2024      August   Thursday
# 19        2024        July     Sunday
# 22        2024       March  Wednesday

# %% [markdown]
# ## Task 27
#
# Filter all rows where Payment_Method is UPI.

# %%
df[df['Payment_Method'] == 'UPI'].head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 2   09ORD100741 2025-03-17       Bird Owner    South         Grooming
# 3   09ORD100661 2024-01-30        Cat Owner     West         Grooming
# 4   09ORD100412 2024-10-27        Cat Owner    South      Accessories
# 9   09ORD100137 2025-06-02       Bird Owner  Central             Food
# 18  09ORD100762 2024-03-20        Dog Owner     East      Accessories
#
#    Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 2             UPI         2     2085.62                22      3253.57
# 3             UPI         4     6568.81                25     19706.43
# 4             UPI         4     7566.14                21     23909.00
# 9             UPI         6     1484.59                 3      8640.31
# 18            UPI         3      672.27                25      1512.61
#
#     Order_Year Order_Month  Order_Day
# 2         2025       March     Monday
# 3         2024     January    Tuesday
# 4         2024     October     Sunday
# 9         2025        June     Monday
# 18        2024       March  Wednesday

# %% [markdown]
# ## Task 28
#
# Filter all rows where Quantity is greater than 3.

# %%
df[df['Quantity'] > 3].head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0   09ORD100522 2025-09-20        Cat Owner     East      Accessories
# 3   09ORD100661 2024-01-30        Cat Owner     West         Grooming
# 4   09ORD100412 2024-10-27        Cat Owner    South      Accessories
# 9   09ORD100137 2025-06-02       Bird Owner  Central             Food
# 11  09ORD100077 2024-02-08        Dog Owner    North         Grooming
#
#    Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0          Wallet         6      316.57                 4      1823.44
# 3             UPI         4     6568.81                25     19706.43
# 4             UPI         4     7566.14                21     23909.00
# 9             UPI         6     1484.59                 3      8640.31
# 11    Credit Card         4     4653.64                16     15636.23
#
#     Order_Year Order_Month Order_Day
# 0         2025   September  Saturday
# 3         2024     January   Tuesday
# 4         2024     October    Sunday
# 9         2025        June    Monday
# 11        2024    February  Thursday

# %% [markdown]
# ## Task 29
#
# Filter all rows where Order_Value is above 5000.

# %%
df[df['Order_Value'] > 5000].head()
# Out:
#       Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 1  09ORD100738 2024-07-17        Dog Owner     East             Food
# 3  09ORD100661 2024-01-30        Cat Owner     West         Grooming
# 4  09ORD100412 2024-10-27        Cat Owner    South      Accessories
# 5  09ORD100679 2024-09-22        Dog Owner  Central       Healthcare
# 7  09ORD100514 2025-02-02         Pet Shop  Central             Toys
#
#      Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 1        Debit Card         2     3613.55                14      6215.31
# 3               UPI         4     6568.81                25     19706.43
# 4               UPI         4     7566.14                21     23909.00
# 5       Credit Card         1     6892.45                14      5927.51
# 7  Cash on Delivery         1     7549.88                 3      7323.38
#
#    Order_Year Order_Month  Order_Day
# 1        2024        July  Wednesday
# 3        2024     January    Tuesday
# 4        2024     October     Sunday
# 5        2024   September     Sunday
# 7        2025    February     Sunday

# %% [markdown]
# ## Task 30
#
# Filter rows where Discount_Percent is between 10 and 20.

# %%
df[df['Discount_Percent'].between(10,20)].head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 1   09ORD100738 2024-07-17        Dog Owner     East             Food
# 5   09ORD100679 2024-09-22        Dog Owner  Central       Healthcare
# 11  09ORD100077 2024-02-08        Dog Owner    North         Grooming
# 13  09ORD100974 2024-08-01        Dog Owner    North             Toys
# 15  09ORD100900 2025-03-27       Bird Owner     East             Toys
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 1         Debit Card         2     3613.55                14      6215.31
# 5        Credit Card         1     6892.45                14      5927.51
# 11       Credit Card         4     4653.64                16     15636.23
# 13  Cash on Delivery         2      990.97                20      1585.55
# 15            Wallet         4     2780.71                20      8898.27
#
#     Order_Year Order_Month  Order_Day
# 1         2024        July  Wednesday
# 5         2024   September     Sunday
# 11        2024    February   Thursday
# 13        2024      August   Thursday
# 15        2025       March   Thursday

# %% [markdown]
# ## Task 31
#
# Filter rows where Product_Category belongs to a given list of two categories.

# %%
filtered_df = df[df['Product_Category'].isin(['Food', 'Toys'])]
filtered_df.head()
# df[df['Product_Category'].isin(df['Product_Category'].unique()[:2])].head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 1   09ORD100738 2024-07-17        Dog Owner     East             Food
# 6   09ORD100627 2024-04-10         Pet Shop  Central             Toys
# 7   09ORD100514 2025-02-02         Pet Shop  Central             Toys
# 9   09ORD100137 2025-06-02       Bird Owner  Central             Food
# 12  09ORD100637 2024-12-04        Dog Owner     East             Food
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 1         Debit Card         2     3613.55                14      6215.31
# 6        Credit Card         3      633.35                24      1444.04
# 7   Cash on Delivery         1     7549.88                 3      7323.38
# 9                UPI         6     1484.59                 3      8640.31
# 12            Wallet         6     3529.30                30     14823.06
#
#     Order_Year Order_Month  Order_Day
# 1         2024        July  Wednesday
# 6         2024       April  Wednesday
# 7         2025    February     Sunday
# 9         2025        June     Monday
# 12        2024    December  Wednesday

# %% [markdown]
# ## Task 32
#
# Find all unique values in Customer_Segment.

# %%
df['Customer_Segment'].unique()
# Out:
# <StringArray>
# ['Cat Owner', 'Dog Owner', 'Bird Owner', 'Pet Shop']
# Length: 4, dtype: str

# %% [markdown]
# ## Task 33
#
# Count the number of unique values in Product_Category.

# %%
df['Product_Category'].nunique()
# Out:
# 5

# %% [markdown]
# ## Task 34
#
# Display value counts for Region.

# %%
df['Region'].value_counts()
# Out:
# Region
# West       223
# Central    198
# East       197
# North      197
# South      185
# Name: count, dtype: int64

# %% [markdown]
# ## Task 35
#
# Display value counts for Payment_Method.

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# UPI                 210
# Wallet              207
# Cash on Delivery    197
# Credit Card         195
# Debit Card          191
# Name: count, dtype: int64

# %% [markdown]
# ## Task 36
#
# Find the minimum, maximum, and mean of Unit_Price.

# %%
df['Unit_Price'].agg(['min','max','mean'])
# Out:
# min       53.73000
# max     8989.20000
# mean    4500.64764
# Name: Unit_Price, dtype: float64

# %% [markdown]
# ## Task 37
#
# Find the total sum of Order_Value.

# %%
df['Order_Value'].sum()
# Out:
# np.float64(10272179.51)

# %% [markdown]
# ## Task 38
#
# Find the median of Quantity.

# %%
df['Quantity'].median()
# Out:
# np.float64(2.0)

# %% [markdown]
# ## Task 39
#
# Find the standard deviation of Order_Value.

# %%
df['Order_Value'].std()
# Out:
# np.float64(9554.934117924704)

# %% [markdown]
# ## Task 40
#
# Create a new column Gross_Value as Quantity multiplied by Unit_Price.

# %%
df['Gross_Value'] = df['Quantity'] * df['Unit_Price']
df[['Quantity','Unit_Price','Gross_Value']].head()
# Out:
#    Quantity  Unit_Price  Gross_Value
# 0         6      316.57      1899.42
# 1         2     3613.55      7227.10
# 2         2     2085.62      4171.24
# 3         4     6568.81     26275.24
# 4         4     7566.14     30264.56

# %% [markdown]
# ## Task 41
#
# Verify whether Gross_Value and Order_Value are consistent after discount calculation.

# %%
x=df['Discount_Percent']/100
df['Expected_Order_Value'] = (df['Gross_Value'] * (1 -x))
(df['Expected_Order_Value'] == df['Order_Value']).value_counts()
# Out:
# False    935
# True      65
# Name: count, dtype: int64

# %% [markdown]
# ## Task 42
#
# Create a new column Discount_Amount.

# %%
df['Discount_Amount'] = (df['Gross_Value'] - df['Order_Value'])
df[['Gross_Value','Order_Value','Discount_Amount']].head()
# Out:
#    Gross_Value  Order_Value  Discount_Amount
# 0      1899.42      1823.44            75.98
# 1      7227.10      6215.31          1011.79
# 2      4171.24      3253.57           917.67
# 3     26275.24     19706.43          6568.81
# 4     30264.56     23909.00          6355.56

# %% [markdown]
# ## Task 43
#
# Create a new column High_Value_Order where Order_Value > 5000 is Yes otherwise No.

# %%
df['High_Value_Order'] = np.where(df['Order_Value'] > 5000, 'Yes', 'No')
df[['Order_Value','High_Value_Order']].head()
# Out:
#    Order_Value High_Value_Order
# 0      1823.44               No
# 1      6215.31              Yes
# 2      3253.57               No
# 3     19706.43              Yes
# 4     23909.00              Yes

# %% [markdown]
# ## Task 44
#
# Use apply() to categorize Unit_Price into Low, Medium, High.

# %%
def price(x):
    if x < df['Unit_Price'].quantile(0.33):
        return 'Low'
    elif x < df['Unit_Price'].quantile(0.66):
        return 'Medium'
    return 'High'

df['Price'] = df['Unit_Price'].apply(price)
df[['Unit_Price','Price']].head()
# Out:
#    Unit_Price   Price
# 0      316.57     Low
# 1     3613.55  Medium
# 2     2085.62     Low
# 3     6568.81    High
# 4     7566.14    High

# %% [markdown]
# ## Task 45
#
# Find the top 10 highest Order_Value rows.

# %%
df.sort_values(by='Order_Value',ascending=False).head(10)
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 601  09ORD100128 2025-11-11        Cat Owner  Central         Grooming
# 505  09ORD100961 2025-11-14        Cat Owner     West             Food
# 178  09ORD100803 2024-03-15       Bird Owner    South      Accessories
# 158  09ORD100061 2025-03-16       Bird Owner    North             Toys
# 589  09ORD100176 2025-06-25       Bird Owner  Central       Healthcare
# 640  09ORD100365 2024-12-25       Bird Owner     West       Healthcare
# 92   09ORD100523 2024-09-06       Bird Owner    North             Food
# 523  09ORD100341 2024-07-11        Cat Owner    South         Grooming
# 384  09ORD100221 2025-08-16       Bird Owner     East         Grooming
# 22   09ORD100372 2024-03-06        Cat Owner    North       Healthcare
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 601        Debit Card         6     8731.26                 1     51863.68
# 505        Debit Card         6     8305.05                 0     49830.30
# 178       Credit Card         6     8423.89                 3     49027.04
# 158        Debit Card         6     8946.68                16     45091.27
# 589  Cash on Delivery         6     8214.72                10     44359.49
# 640               UPI         6     7448.63                 1     44244.86
# 92        Credit Card         6     8215.45                11     43870.50
# 523  Cash on Delivery         5     8723.66                 2     42745.93
# 384            Wallet         6     7527.97                 7     42006.07
# 22                UPI         6     6997.30                 0     41983.80
#
#      Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 601        2025    November    Tuesday     52387.56            51863.6844
# 505        2025    November     Friday     49830.30            49830.3000
# 178        2024       March     Friday     50543.34            49027.0398
# 158        2025       March     Sunday     53680.08            45091.2672
# 589        2025        June  Wednesday     49288.32            44359.4880
# 640        2024    December  Wednesday     44691.78            44244.8622
# 92         2024   September     Friday     49292.70            43870.5030
# 523        2024        July   Thursday     43618.30            42745.9340
# 384        2025      August   Saturday     45167.82            42006.0726
# 22         2024       March  Wednesday     41983.80            41983.8000
#
#      Discount_Amount High_Value_Order Price
# 601     5.238800e+02              Yes  High
# 505    -7.275958e-12              Yes  High
# 178     1.516300e+03              Yes  High
# 158     8.588810e+03              Yes  High
# 589     4.928830e+03              Yes  High
# 640     4.469200e+02              Yes  High
# 92      5.422200e+03              Yes  High
# 523     8.723700e+02              Yes  High
# 384     3.161750e+03              Yes  High
# 22      0.000000e+00              Yes  High

# %% [markdown]
# ## Task 46
#
# Find the bottom 10 lowest Order_Value rows.

# %%
df.sort_values(by='Order_Value').head(10)
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 256  09ORD100520 2024-08-16        Dog Owner    North         Grooming
# 407  09ORD100339 2024-06-19        Dog Owner     East         Grooming
# 930  09ORD100565 2025-05-03         Pet Shop     West             Food
# 771  09ORD100677 2025-06-13       Bird Owner  Central         Grooming
# 473  09ORD100090 2025-04-19        Cat Owner    South             Food
# 768  09ORD100843 2024-06-27        Cat Owner    North             Food
# 188  09ORD100943 2025-03-04        Cat Owner     East      Accessories
# 430  09ORD100286 2025-08-22         Pet Shop     West         Grooming
# 102  09ORD100937 2024-09-07       Bird Owner    South      Accessories
# 229  09ORD100537 2024-02-18       Bird Owner    North         Grooming
#
#     Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 256    Credit Card         1       53.73                 6        50.51
# 407         Wallet         2       85.36                28       122.92
# 930         Wallet         1      157.77                18       129.37
# 771         Wallet         1      169.17                21       133.64
# 473            UPI         1      207.01                27       151.12
# 768     Debit Card         4       55.40                30       155.12
# 188     Debit Card         1      218.64                29       155.23
# 430         Wallet         2      115.32                24       175.29
# 102         Wallet         1      216.93                19       175.71
# 229            UPI         1      199.54                 4       191.56
#
#      Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 256        2024      August     Friday        53.73               50.5062
# 407        2024        June  Wednesday       170.72              122.9184
# 930        2025         May   Saturday       157.77              129.3714
# 771        2025        June     Friday       169.17              133.6443
# 473        2025       April   Saturday       207.01              151.1173
# 768        2024        June   Thursday       221.60              155.1200
# 188        2025       March    Tuesday       218.64              155.2344
# 430        2025      August     Friday       230.64              175.2864
# 102        2024   September   Saturday       216.93              175.7133
# 229        2024    February     Sunday       199.54              191.5584
#
#      Discount_Amount High_Value_Order Price
# 256             3.22               No   Low
# 407            47.80               No   Low
# 930            28.40               No   Low
# 771            35.53               No   Low
# 473            55.89               No   Low
# 768            66.48               No   Low
# 188            63.41               No   Low
# 430            55.35               No   Low
# 102            41.22               No   Low
# 229             7.98               No   Low

# %% [markdown]
# ## Task 47
#
# Group by Region and calculate average Order_Value.

# %%
df.groupby('Region')['Order_Value'].mean()
# Out:
# Region
# Central    10372.028081
# East        8307.432081
# North      11013.774518
# South      10493.947081
# West       11080.089865
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 48
#
# Group by Product_Category and calculate total sales.

# %%
df.groupby('Product_Category')['Order_Value'].sum().sort_values(ascending=False)
# Out:
# Product_Category
# Food           2322132.17
# Grooming       2200808.97
# Toys           2127593.43
# Healthcare     1928118.10
# Accessories    1693526.84
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 49
#
# Group by Payment_Method and calculate total Quantity sold.

# %%
df.groupby('Payment_Method')['Quantity'].sum()
# Out:
# Payment_Method
# Cash on Delivery    548
# Credit Card         552
# Debit Card          511
# UPI                 571
# Wallet              551
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Task 50
#
# Group by Customer_Segment and calculate average discount percentage.

# %%
df.groupby('Customer_Segment')['Discount_Percent'].mean()
# Out:
# Customer_Segment
# Bird Owner    15.158103
# Cat Owner     15.149194
# Dog Owner     15.937255
# Pet Shop      15.241803
# Name: Discount_Percent, dtype: float64

# %% [markdown]
# ## Task 51
#
# Perform multi-level grouping by Region and Product_Category and compute total Order_Value.

# %%
df.groupby(['Region','Product_Category'])['Order_Value'].sum()
# Out:
# Region   Product_Category
# Central  Accessories         321338.12
#          Food                538661.94
#          Grooming            486887.20
#          Healthcare          384787.52
#          Toys                321986.78
# East     Accessories         216908.49
#          Food                462617.32
#          Grooming            387359.46
#          Healthcare          219450.39
#          Toys                350228.46
# North    Accessories         327596.18
#          Food                414595.14
#          Grooming            379355.46
#          Healthcare          487199.28
#          Toys                560967.52
# South    Accessories         473778.48
#          Food                312952.80
#          Grooming            451997.78
#          Healthcare          306839.25
#          Toys                395811.90
# West     Accessories         353905.57
#          Food                593304.97
#          Grooming            495209.07
#          Healthcare          529841.66
#          Toys                498598.77
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 52
#
# Aggregate Quantity, Unit_Price, and Order_Value with multiple statistics using agg().

# %%
df[['Quantity','Unit_Price','Order_Value']].agg(['min','max','mean','sum'])
# Out:
#       Quantity    Unit_Price   Order_Value
# min      1.000  5.373000e+01  5.051000e+01
# max      6.000  8.989200e+03  5.186368e+04
# mean     2.733  4.500648e+03  1.027218e+04
# sum   2733.000  4.500648e+06  1.027218e+07

# %% [markdown]
# ## Task 53
#
# Create a pivot table showing total Order_Value by Region and Payment_Method.

# %%
pd.pivot_table(df, values='Order_Value', index='Region', columns='Payment_Method', aggfunc='sum', fill_value=0)
# Out:
# Payment_Method  Cash on Delivery  Credit Card  Debit Card        UPI  \
# Region
# Central                407532.45    506456.36   374083.99  425355.26
# East                   344292.81    300804.05   219994.16  283009.82
# North                  466762.00    511250.77   387067.88  472880.60
# South                  439296.86    216558.91   552040.41  352014.02
# West                   549404.23    551071.07   402115.95  518256.57
#
# Payment_Method     Wallet
# Region
# Central         340233.50
# East            488463.28
# North           331752.33
# South           381470.01
# West            450012.22

# %% [markdown]
# ## Task 54
#
# Create a pivot table showing average Unit_Price by Product_Category and Customer_Segment.

# %%
pd.pivot_table(df, values='Unit_Price', index='Product_Category', columns='Customer_Segment', aggfunc='mean', fill_value=0)
# Out:
# Customer_Segment   Bird Owner    Cat Owner    Dog Owner     Pet Shop
# Product_Category
# Accessories       4740.925143  4502.360962  4386.678727  4184.332308
# Food              4519.548983  4774.790820  4474.761731  3741.367407
# Grooming          4503.057213  5143.247959  3972.134118  4397.674783
# Healthcare        4724.200455  4506.330465  3798.955789  4681.271923
# Toys              4734.376667  4991.090465  4531.081864  4620.585849

# %% [markdown]
# ## Task 55
#
# Count the number of orders placed in each month.

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

orders_per_month = (
    df.groupby(df['Order_Date'].dt.to_period('M'))
      .size()
)

print(orders_per_month)
# Out:
# Order_Date
# 2024-01    55
# 2024-02    37
# 2024-03    47
# 2024-04    44
# 2024-05    37
# 2024-06    49
# 2024-07    44
# 2024-08    44
# 2024-09    46
# 2024-10    38
# 2024-11    42
# 2024-12    43
# 2025-01    31
# 2025-02    44
# 2025-03    42
# 2025-04    31
# 2025-05    53
# 2025-06    32
# 2025-07    41
# 2025-08    34
# 2025-09    39
# 2025-10    37
# 2025-11    42
# 2025-12    48
# Freq: M, dtype: int64

# %% [markdown]
# ## Task 56
#
# Find the month with the highest total sales.

# %%
monthly_sales = df.groupby(df['Order_Date'].dt.month_name())['Order_Value'].sum()
monthly_sales.sort_values(ascending=False).head(1)
# Out:
# Order_Date
# March    1040874.41
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 57
#
# Find the region with the highest average order value.

# %%
df.groupby('Region')['Order_Value'].mean().sort_values(ascending=False).head(1)
# Out:
# Region
# West    11080.089865
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 58
#
# Find the product category with the highest total quantity sold.

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_Segment', 'Region',
#        'Product_Category', 'Payment_Method', 'Quantity', 'Unit_Price',
#        'Discount_Percent', 'Order_Value', 'Order_Year', 'Order_Month',
#        'Order_Day', 'Gross_Value', 'Expected_Order_Value', 'Discount_Amount',
#        'High_Value_Order', 'Price'],
#       dtype='str')

# %%
df.groupby('Product_Category')['Quantity'].sum().sort_values(ascending=False).head(1)
# Out:
# Product_Category
# Food    627
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Task 59
#
# Use query() to filter rows where Quantity >= 2 and Discount_Percent >= 15.

# %%
df.query('Quantity >= 2 and Discount_Percent >= 15').head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 2   09ORD100741 2025-03-17       Bird Owner    South         Grooming
# 3   09ORD100661 2024-01-30        Cat Owner     West         Grooming
# 4   09ORD100412 2024-10-27        Cat Owner    South      Accessories
# 6   09ORD100627 2024-04-10         Pet Shop  Central             Toys
# 10  09ORD100812 2025-02-25        Dog Owner     East      Accessories
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 2                UPI         2     2085.62                22      3253.57
# 3                UPI         4     6568.81                25     19706.43
# 4                UPI         4     7566.14                21     23909.00
# 6        Credit Card         3      633.35                24      1444.04
# 10  Cash on Delivery         2     1113.34                23      1714.54
#
#     Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 2         2025       March     Monday      4171.24             3253.5672
# 3         2024     January    Tuesday     26275.24            19706.4300
# 4         2024     October     Sunday     30264.56            23909.0024
# 6         2024       April  Wednesday      1900.05             1444.0380
# 10        2025    February    Tuesday      2226.68             1714.5436
#
#     Discount_Amount High_Value_Order Price
# 2            917.67               No   Low
# 3           6568.81              Yes  High
# 4           6355.56              Yes  High
# 6            456.01               No   Low
# 10           512.14               No   Low

# %% [markdown]
# ## Task 60
#
# Select only Order_ID, Region, Product_Category, and Order_Value columns.

# %%
df[['Order_ID','Product_Category','Order_Value']]
# Out:
#         Order_ID Product_Category  Order_Value
# 0    09ORD100522      Accessories      1823.44
# 1    09ORD100738             Food      6215.31
# 2    09ORD100741         Grooming      3253.57
# 3    09ORD100661         Grooming     19706.43
# 4    09ORD100412      Accessories     23909.00
# ..           ...              ...          ...
# 995  09ORD100107      Accessories      4174.78
# 996  09ORD100271       Healthcare     14330.50
# 997  09ORD100861         Grooming     15713.82
# 998  09ORD100436             Food      1111.10
# 999  09ORD100103       Healthcare     14531.64
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Task 61
#
# Reorder the columns in any meaningful custom order.

# %%
df[['Order_ID','Order_Date','Region','Customer_Segment','Product_Category','Payment_Method','Quantity','Unit_Price','Discount_Percent','Order_Value']].head()
# Out:
#       Order_ID Order_Date Region Customer_Segment Product_Category  \
# 0  09ORD100522 2025-09-20   East        Cat Owner      Accessories
# 1  09ORD100738 2024-07-17   East        Dog Owner             Food
# 2  09ORD100741 2025-03-17  South       Bird Owner         Grooming
# 3  09ORD100661 2024-01-30   West        Cat Owner         Grooming
# 4  09ORD100412 2024-10-27  South        Cat Owner      Accessories
#
#   Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 0         Wallet         6      316.57                 4      1823.44
# 1     Debit Card         2     3613.55                14      6215.31
# 2            UPI         2     2085.62                22      3253.57
# 3            UPI         4     6568.81                25     19706.43
# 4            UPI         4     7566.14                21     23909.00

# %% [markdown]
# ## Task 62
#
# Find rows where Order_Value is above the overall average order value.

# %%
df[df['Order_Value'] > df['Order_Value'].mean()].head()
# Out:
#        Order_ID Order_Date Customer_Segment Region Product_Category  \
# 3   09ORD100661 2024-01-30        Cat Owner   West         Grooming
# 4   09ORD100412 2024-10-27        Cat Owner  South      Accessories
# 11  09ORD100077 2024-02-08        Dog Owner  North         Grooming
# 12  09ORD100637 2024-12-04        Dog Owner   East             Food
# 14  09ORD100939 2025-02-26        Cat Owner   East       Healthcare
#
#    Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 3             UPI         4     6568.81                25     19706.43
# 4             UPI         4     7566.14                21     23909.00
# 11    Credit Card         4     4653.64                16     15636.23
# 12         Wallet         6     3529.30                30     14823.06
# 14         Wallet         6     3761.39                 6     21214.24
#
#     Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 3         2024     January    Tuesday     26275.24            19706.4300
# 4         2024     October     Sunday     30264.56            23909.0024
# 11        2024    February   Thursday     18614.56            15636.2304
# 12        2024    December  Wednesday     21175.80            14823.0600
# 14        2025    February  Wednesday     22568.34            21214.2396
#
#     Discount_Amount High_Value_Order   Price
# 3           6568.81              Yes    High
# 4           6355.56              Yes    High
# 11          2978.33              Yes  Medium
# 12          6352.74              Yes  Medium
# 14          1354.10              Yes  Medium

# %% [markdown]
# ## Task 63
#
# Find rows where Unit_Price is below the 25th percentile.

# %%
df[df['Unit_Price'] < df['Unit_Price'].quantile(0.25)].head()
# Out:
#       Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0  09ORD100522 2025-09-20        Cat Owner     East      Accessories
# 2  09ORD100741 2025-03-17       Bird Owner    South         Grooming
# 6  09ORD100627 2024-04-10         Pet Shop  Central             Toys
# 8  09ORD100860 2025-08-26         Pet Shop    North      Accessories
# 9  09ORD100137 2025-06-02       Bird Owner  Central             Food
#
#   Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0         Wallet         6      316.57                 4      1823.44
# 2            UPI         2     2085.62                22      3253.57
# 6    Credit Card         3      633.35                24      1444.04
# 8    Credit Card         2     2078.56                 1      4115.55
# 9            UPI         6     1484.59                 3      8640.31
#
#    Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 0        2025   September   Saturday      1899.42             1823.4432
# 2        2025       March     Monday      4171.24             3253.5672
# 6        2024       April  Wednesday      1900.05             1444.0380
# 8        2025      August    Tuesday      4157.12             4115.5488
# 9        2025        June     Monday      8907.54             8640.3138
#
#    Discount_Amount High_Value_Order Price
# 0            75.98               No   Low
# 2           917.67               No   Low
# 6           456.01               No   Low
# 8            41.57               No   Low
# 9           267.23              Yes   Low

# %% [markdown]
# ## Task 64
#
# Find the correlation between Quantity, Unit_Price, Discount_Percent, and Order_Value.

# %%
df[['Quantity','Unit_Price','Discount_Percent','Order_Value']].corr()
# Out:
#                   Quantity  Unit_Price  Discount_Percent  Order_Value
# Quantity          1.000000   -0.038167          0.031552     0.680236
# Unit_Price       -0.038167    1.000000         -0.017148     0.572656
# Discount_Percent  0.031552   -0.017148          1.000000    -0.119301
# Order_Value       0.680236    0.572656         -0.119301     1.000000

# %% [markdown]
# ## Task 65
#
# Export the top 50 highest value orders to a CSV file.

# %%
df.nlargest(50, 'Order_Value').to_csv('top_50_high_value_orders.csv', index=False)

# %% [markdown]
# ## Task 66
#
# Create a bar chart of total Order_Value by Region using Matplotlib.

# %%
region_sales = df.groupby('Region')['Order_Value'].sum().sort_values()
region_sales.plot(kind='bar')
plt.title('Total Order Value by Region')
plt.xlabel('Region')
plt.ylabel('Order Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 67
#
# Create a bar chart of total Quantity sold by Product_Category using Seaborn.

# %%
# product_sales = df.groupby('Product_Category')['Quantity'].sum().sort_values()
# product_sales.plot(kind='bar')
# plt.title('Total Quantity sold by Product_Category')
# plt.xlabel('Product Category')
# plt.ylabel('Quantity')
# plt.tight_layout()
# plt.show()

plt.figure(figsize=(8,4))
sns.barplot(data=df.groupby('Product_Category', as_index=False)['Quantity'].sum(), x='Product_Category', y='Quantity')
plt.xticks(rotation=45)
plt.title('Total Quantity by Product Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 68
#
# Create a histogram of Unit_Price using Matplotlib.

# %% [markdown]
# ## Task 69
#
# Create a histogram of Order_Value with KDE using Seaborn.

# %% [markdown]
# ## Task 70
#
# Create a boxplot of Order_Value by Region.

# %% [markdown]
# ## Task 71
#
# Create a boxplot of Unit_Price by Payment_Method.

# %% [markdown]
# ## Task 72
#
# Create a countplot of Customer_Segment.

# %% [markdown]
# ## Task 73
#
# Create a pie chart of Payment_Method distribution.

# %% [markdown]
# ## Task 74
#
# Create a line chart of monthly total sales.

# %% [markdown]
# ## Task 75
#
# Create a heatmap of correlation among numerical columns.

# %% [markdown]
# ## Task 76
#
# Create a scatter plot of Unit_Price vs Order_Value.

# %% [markdown]
# ## Task 77
#
# Create a scatter plot of Quantity vs Order_Value colored by Region using Seaborn.

# %% [markdown]
# ## Task 78
#
# Create a violin plot of Order_Value by Product_Category.

# %% [markdown]
# ## Task 79
#
# Create a stacked bar style plot of monthly sales by Region.

# %% [markdown]
# ## Task 80
#
# Create a pairplot for Quantity, Unit_Price, Discount_Percent, and Order_Value.
